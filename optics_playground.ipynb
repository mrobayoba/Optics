# %%
import fresnel as fresnel

# Caso 1: Aire a Vidrio (Reflexión Externa)
fresnel.graficar_reflectancia(ni=1.0, nt=1.5)

# Caso 2: Vidrio a Aire (Reflexión Interna y Ángulo Crítico)
fresnel.graficar_reflectancia(ni=1.5, nt=1.0)
# Out:
# d:\GitHub\Optics\fresnel.py:21: RuntimeWarning: invalid value encountered in scalar divide
#   rs = -np.sin(theta_i - theta_t) / np.sin(theta_i + theta_t)
# d:\GitHub\Optics\fresnel.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   rp =  np.tan(theta_i - theta_t) / np.tan(theta_i + theta_t)

# %%
# Ejemplo: Aire (n=1) a Vidrio (n=1.5) con incidencia a 30 grados
res = fresnel.coeficientes_intensidad(1.0, 1.5, 30.0)

print(f"Reflectancia modo s: {res['Rs']:.4f}")
print(f"Transmitancia modo s: {res['Ts']:.4f}")
print(f"Suma (Energía): {res['Rs'] + res['Ts']:.1f}")
# Out:
# Reflectancia modo s: 0.0578
# Transmitancia modo s: 0.9422
# Suma (Energía): 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import interferencia as io

# Definir el rango de ángulos de 0 a pi
angulos = np.linspace(0, np.pi, 200)
